# %% [markdown]
# # Assignment 2_Q1

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Measure_X=pd.Series([24.23,25.53,25.41,24.14,29.62,28.25,25.81,24.39,40.26,32.95,91.36,25.99,39.42,26.71,35.00])

# %%
Company_name=['Allied Signal','Bankers Trust','General Mills','ITT Industries','J.P.Morgan Co','Lehman Brothers','Marriott','MCI','Merrill Lynch','Microsoft','Morgan Stanley','Sun Microsystems','Travelers','US Airway','Warner-Lambert']

# %%
#Draw a Pie chart
plt.figure(figsize=(8,10))
plt.pie(Measure_X,labels=Company_name,autopct='%1.0f%%')
plt.show()

# %% [markdown]
# # Boxplot to find Outliers

# %%
sns.boxplot(Measure_X)

# %%
#there is one outlier which is near to 90 or 91

# %%
Measure_X.mean() #To find μ = Mean
# Out:
# 33.27133333333333

# %%
Measure_X.var() #To find σ = Variance
# Out:
# 287.1466123809524

# %%
Measure_X.std() #To find σ^2 = Std
# Out:
# 16.945400921222028
